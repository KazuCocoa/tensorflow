# %% [markdown]
# Deep Learning
# =============
#
# Assignment 5
# ------------
#
# The goal of this assignment is to train a Word2Vec skip-gram model over [Text8](http://mattmahoney.net/dc/textdata) data.

# %%
# These are all the modules we'll be using later. Make sure you can import them
# before proceeding further.
# %matplotlib inline
from __future__ import print_function
import collections
import math
import numpy as np
import os
import random
import tensorflow as tf
import zipfile
from matplotlib import pylab
from six.moves import range
from six.moves.urllib.request import urlretrieve
from sklearn.manifold import TSNE

# %% [markdown]
# Download the data from the source website if necessary.

# %%
url = 'http://mattmahoney.net/dc/'

def maybe_download(filename, expected_bytes):
  """Download a file if not present, and make sure it's the right size."""
  if not os.path.exists(filename):
    filename, _ = urlretrieve(url + filename, filename)
  statinfo = os.stat(filename)
  if statinfo.st_size == expected_bytes:
    print('Found and verified %s' % filename)
  else:
    print(statinfo.st_size)
    raise Exception(
      'Failed to verify ' + filename + '. Can you get to it with a browser?')
  return filename

filename = maybe_download('text8.zip', 31344016)
# Out:
# Found and verified text8.zip

# %% [markdown]
# Read the data into a string.

# %%
def read_data(filename):
  """Extract the first file enclosed in a zip file as a list of words"""
  with zipfile.ZipFile(filename) as f:
    data = tf.compat.as_str(f.read(f.namelist()[0])).split()
  return data
  
words = read_data(filename)
print('Data size %d' % len(words))
# Out:
# Data size 17005207

# %% [markdown]
# Build the dictionary and replace rare words with UNK token.

# %%
vocabulary_size = 50000

def build_dataset(words):
  count = [['UNK', -1]]
  count.extend(collections.Counter(words).most_common(vocabulary_size - 1))
  dictionary = dict()
  for word, _ in count:
    dictionary[word] = len(dictionary)
  data = list()
  unk_count = 0
  for word in words:
    if word in dictionary:
      index = dictionary[word]
    else:
      index = 0  # dictionary['UNK']
      unk_count = unk_count + 1
    data.append(index)
  count[0][1] = unk_count
  reverse_dictionary = dict(zip(dictionary.values(), dictionary.keys())) 
  return data, count, dictionary, reverse_dictionary

data, count, dictionary, reverse_dictionary = build_dataset(words)
print('Most common words (+UNK)', count[:5])
print('Sample data', data[:10])
del words  # Hint to reduce memory.
# Out:
# Most common words (+UNK) [['UNK', 418391], ('the', 1061396), ('of', 593677), ('and', 416629), ('one', 411764)]
# Sample data [5241, 3084, 12, 6, 195, 2, 3135, 46, 59, 156]

# %% [markdown]
# Function to generate a training batch for the skip-gram model.

# %%
data_index = 0

def generate_batch(batch_size, num_skips, skip_window):
  global data_index
  assert batch_size % num_skips == 0
  assert num_skips <= 2 * skip_window
  batch = np.ndarray(shape=(batch_size), dtype=np.int32)
  labels = np.ndarray(shape=(batch_size, 1), dtype=np.int32)
  span = 2 * skip_window + 1 # [ skip_window target skip_window ]
  buffer = collections.deque(maxlen=span)
  for _ in range(span):
    buffer.append(data[data_index])
    data_index = (data_index + 1) % len(data)
  for i in range(batch_size // num_skips):
    target = skip_window  # target label at the center of the buffer
    targets_to_avoid = [ skip_window ]
    for j in range(num_skips):
      while target in targets_to_avoid:
        target = random.randint(0, span - 1)
      targets_to_avoid.append(target)
      batch[i * num_skips + j] = buffer[skip_window]
      labels[i * num_skips + j, 0] = buffer[target]
    buffer.append(data[data_index])
    data_index = (data_index + 1) % len(data)
  return batch, labels

print('data:', [reverse_dictionary[di] for di in data[:8]])

for num_skips, skip_window in [(2, 1), (4, 2)]:
    data_index = 0
    batch, labels = generate_batch(batch_size=8, num_skips=num_skips, skip_window=skip_window)
    print('\nwith num_skips = %d and skip_window = %d:' % (num_skips, skip_window))
    print('    batch:', [reverse_dictionary[bi] for bi in batch])
    print('    labels:', [reverse_dictionary[li] for li in labels.reshape(8)])
# Out:
# data: ['anarchism', 'originated', 'as', 'a', 'term', 'of', 'abuse', 'first']
#
# with num_skips = 2 and skip_window = 1:
#     batch: ['originated', 'originated', 'as', 'as', 'a', 'a', 'term', 'term']
#     labels: ['as', 'anarchism', 'a', 'originated', 'term', 'as', 'a', 'of']
#
# with num_skips = 4 and skip_window = 2:
#     batch: ['as', 'as', 'as', 'as', 'a', 'a', 'a', 'a']
#     labels: ['anarchism', 'originated', 'a', 'term', 'of', 'originated', 'term', 'as']

# %% [markdown]
# Train a skip-gram model.

# %%
batch_size = 128
embedding_size = 128 # Dimension of the embedding vector.
skip_window = 1 # How many words to consider left and right.
num_skips = 2 # How many times to reuse an input to generate a label.
# We pick a random validation set to sample nearest neighbors. here we limit the
# validation samples to the words that have a low numeric ID, which by
# construction are also the most frequent. 
valid_size = 16 # Random set of words to evaluate similarity on.
valid_window = 100 # Only pick dev samples in the head of the distribution.
valid_examples = np.array(random.sample(range(valid_window), valid_size))
num_sampled = 64 # Number of negative examples to sample.

graph = tf.Graph()

with graph.as_default(), tf.device('/cpu:0'):

  # Input data.
  train_dataset = tf.placeholder(tf.int32, shape=[batch_size])
  train_labels = tf.placeholder(tf.int32, shape=[batch_size, 1])
  valid_dataset = tf.constant(valid_examples, dtype=tf.int32)
  
  # Variables.
  embeddings = tf.Variable(
    tf.random_uniform([vocabulary_size, embedding_size], -1.0, 1.0))
  softmax_weights = tf.Variable(
    tf.truncated_normal([vocabulary_size, embedding_size],
                         stddev=1.0 / math.sqrt(embedding_size)))
  softmax_biases = tf.Variable(tf.zeros([vocabulary_size]))
  
  # Model.
  # Look up embeddings for inputs.
  embed = tf.nn.embedding_lookup(embeddings, train_dataset)
  # Compute the softmax loss, using a sample of the negative labels each time.
  loss = tf.reduce_mean(
    tf.nn.sampled_softmax_loss(softmax_weights, softmax_biases, embed,
                               train_labels, num_sampled, vocabulary_size))

  # Optimizer.
  # Note: The optimizer will optimize the softmax_weights AND the embeddings.
  # This is because the embeddings are defined as a variable quantity and the
  # optimizer's `minimize` method will by default modify all variable quantities 
  # that contribute to the tensor it is passed.
  # See docs on `tf.train.Optimizer.minimize()` for more details.
  optimizer = tf.train.AdagradOptimizer(1.0).minimize(loss)
  
  # Compute the similarity between minibatch examples and all embeddings.
  # We use the cosine distance:
  norm = tf.sqrt(tf.reduce_sum(tf.square(embeddings), 1, keep_dims=True))
  normalized_embeddings = embeddings / norm
  valid_embeddings = tf.nn.embedding_lookup(
    normalized_embeddings, valid_dataset)
  similarity = tf.matmul(valid_embeddings, tf.transpose(normalized_embeddings))

# %%
num_steps = 100001

with tf.Session(graph=graph) as session:
  tf.initialize_all_variables().run()
  print('Initialized')
  average_loss = 0
  for step in range(num_steps):
    batch_data, batch_labels = generate_batch(
      batch_size, num_skips, skip_window)
    feed_dict = {train_dataset : batch_data, train_labels : batch_labels}
    _, l = session.run([optimizer, loss], feed_dict=feed_dict)
    average_loss += l
    if step % 2000 == 0:
      if step > 0:
        average_loss = average_loss / 2000
      # The average loss is an estimate of the loss over the last 2000 batches.
      print('Average loss at step %d: %f' % (step, average_loss))
      average_loss = 0
    # note that this is expensive (~20% slowdown if computed every 500 steps)
    if step % 10000 == 0:
      sim = similarity.eval()
      for i in range(valid_size):
        valid_word = reverse_dictionary[valid_examples[i]]
        top_k = 8 # number of nearest neighbors
        nearest = (-sim[i, :]).argsort()[1:top_k+1]
        log = 'Nearest to %s:' % valid_word
        for k in range(top_k):
          close_word = reverse_dictionary[nearest[k]]
          log = '%s %s,' % (log, close_word)
        print(log)
  final_embeddings = normalized_embeddings.eval()
# Out:
# Initialized
# Average loss at step 0: 7.745259
# Nearest to or: alchemist, chanter, elton, cherokees, geostationary, decisions, hoc, fitzroy,
# Nearest to some: deactivated, marys, dagny, overture, cats, pittsburg, invertible, pounder,
# Nearest to which: tested, liner, univ, afternoons, shinto, modular, kun, adic,
# Nearest to however: nara, assumption, bees, midway, toil, arcadia, pathophysiology, py,
# Nearest to that: assyrian, grease, xenosaga, adm, ppc, mataram, nicosia, yea,
# Nearest to about: mail, krypton, giger, bearded, brienne, anhalt, mojito, nadu,
# Nearest to between: make, cats, splicing, landmines, confucian, actively, petty, altarpiece,
# Nearest to new: ifad, falcone, moles, anniversaries, collaborating, sheppard, inborn, juggalo,
# Nearest to would: airy, consensual, nfl, sportsman, boopsie, banished, hmso, palos,
# Nearest to use: dolby, hypothesis, apologised, scams, rotation, dissolves, zappa, emeritus,
# Nearest to often: lending, assigning, mirabeau, allegro, jewelry, messiaen, bahasa, sniper,
# Nearest to so: roofed, spotters, headphones, signed, bundaberg, torvalds, faraway, maskhadov,
# Nearest to people: price, rios, steamship, chet, hi, isin, valdes, mcpherson,
# Nearest to to: hazard, socialize, eschewing, age, hallows, subtitled, fiasco, leaped,
# Nearest to a: tba, honduran, syria, phoenicians, carats, diskettes, onshore, mosaics,
# Nearest to history: livelihood, sickly, wormhole, jamahiriya, fossilization, honest, summand, romanticized,
# Average loss at step 2000: 4.357763
# Average loss at step 4000: 3.868951
# Average loss at step 6000: 3.790405
# Average loss at step 8000: 3.682289
# Average loss at step 10000: 3.619072
# Nearest to or: and, heterosexuals, gandy, include, boating, depraved, braille, filkers,
# Nearest to some: many, deactivated, consonants, their, most, each, other, ghosts,
# Nearest to which: that, this, assisted, usually, it, negev, tested, halftime,
# Nearest to however: but, oligocene, pneumonic, myositis, bees, loathed, microkernel, cranberry,
# Nearest to that: which, this, it, presumes, levitation, cleanse, entertainment, frequentist,
# Nearest to about: mail, krypton, disappearing, anhalt, procure, predictability, nadu, mojito,
# Nearest to between: with, cats, moral, make, regarding, while, lagrange, orchestrated,
# Nearest to new: ifad, surpass, infamous, marine, bruxelles, sheppard, dagesh, flickering,
# Nearest to would: can, could, will, may, airy, coolest, banished, boopsie,
# Nearest to use: rotation, magically, apologised, dolby, fonni, hypothesis, scams, saban,
# Nearest to often: castrated, twas, typically, ifc, feeble, patrols, also, substitutes,
# Nearest to so: roofed, aquilegia, impatient, garrison, praise, cyp, cheung, quantization,
# Nearest to people: steamship, price, responses, lexicographic, responsiveness, hijacking, rios, chet,
# Nearest to to: disdained, define, into, hallows, can, fruitarians, ewell, tenuous,
# Nearest to a: the, tba, this, apostates, microkernels, his, societal, gssp,
# Nearest to history: sickly, livelihood, honest, berwick, summand, jamahiriya, troop, officio,
# Average loss at step 12000: 3.606202
# Average loss at step 14000: 3.577663
# Average loss at step 16000: 3.409381
# Average loss at step 18000: 3.452915
# Average loss at step 20000: 3.538032
# Nearest to or: and, than, like, with, raya, twinning, amendments, taunting,
# Nearest to some: many, deactivated, most, these, those, both, several, other,
# Nearest to which: this, that, it, but, also, who, these, and,
# Nearest to however: but, hastings, myositis, loathed, that, oligocene, bees, horsemen,
# Nearest to that: which, this, but, when, arming, however, it, interesting,
# Nearest to about: disappearing, mail, procure, boulder, over, mojito, krypton, busby,
# Nearest to between: with, while, regarding, coventry, laude, lagrange, pharos, meteorological,
# Nearest to new: marine, dagesh, surpass, arrows, kickoff, flat, volatility, bruxelles,
# Nearest to would: could, can, will, may, should, must, cannot, might,
# Nearest to use: cause, fonni, magically, fashioned, apologised, lao, rotation, hypothesis,
# Nearest to often: usually, typically, also, commonly, which, it, who, widely,
# Nearest to so: roofed, impatient, aquilegia, garrison, then, driest, survived, cylindrical,
# Nearest to people: lexicographic, price, steamship, advisor, withholding, responses, hijacking, superfamily,
# Nearest to to: disdained, not, would, ghanima, torturing, can, liberalization, into,
# Nearest to a: this, apostates, the, gssp, tba, any, no, scriptura,
# Nearest to history: honest, list, sickly, livelihood, drowns, troop, government, berwick,
# Average loss at step 22000: 3.503873
# Average loss at step 24000: 3.493431
# Average loss at step 26000: 3.476892
# Average loss at step 28000: 3.482880
# Average loss at step 30000: 3.502724
# Nearest to or: and, though, gandy, but, including, than, ddc, lethe,
# Nearest to some: many, these, several, both, other, all, most, their,
# Nearest to which: this, that, who, but, it, also, these, what,
# Nearest to however: but, that, hastings, although, when, copper, while, pneumonic,
# Nearest to that: which, however, this, but, gangrene, where, because, what,
# Nearest to about: mail, procure, boulder, renounced, kq, on, over, ghost,
# Nearest to between: with, regarding, against, hindsight, while, lagrange, yarmouth, in,
# Nearest to new: dagesh, marine, surpass, bram, theoretical, current, volatility, positives,
# Nearest to would: could, can, will, may, should, must, might, cannot,
# Nearest to use: cause, magically, fashioned, all, change, scams, hypothesis, destructive,
# Nearest to often: sometimes, usually, typically, also, commonly, now, generally, there,
# Nearest to so: roofed, impatient, aquilegia, workman, then, charterer, cyp, gets,
# Nearest to people: lexicographic, price, countries, withholding, responses, loop, hijacking, steamship,
# Nearest to to: would, hazard, disdained, hallows, gf, ghanima, must, can,
# Nearest to a: the, your, montage, another, our, tba, mahogany, very,
# Nearest to history: nga, honest, list, sickly, mecca, troop, outbound, leader,
# Average loss at step 32000: 3.500737
# Average loss at step 34000: 3.495043
# Average loss at step 36000: 3.455496
# Average loss at step 38000: 3.303486
# Average loss at step 40000: 3.423646
# Nearest to or: and, than, patricians, a, sorted, predators, giulio, supergroup,
# Nearest to some: many, these, several, any, both, each, different, their,
# Nearest to which: that, this, who, also, usually, but, it, what,
# Nearest to however: but, that, although, while, hastings, niggers, foreigner, microkernel,
# Nearest to that: which, this, however, what, adr, oneida, also, where,
# Nearest to about: procure, ghost, over, renounced, boulder, kq, feed, mail,
# Nearest to between: with, hindsight, against, regarding, yarmouth, while, among, splicing,
# Nearest to new: dagesh, theoretical, fundamental, marine, bram, current, kriol, surpass,
# Nearest to would: could, will, can, may, should, might, must, cannot,
# Nearest to use: cause, destructive, create, swerve, list, lao, webs, scams,
# Nearest to often: usually, sometimes, commonly, typically, generally, also, frequently, widely,
# Nearest to so: then, aquilegia, roofed, cyp, bb, gets, impatient, workman,
# Nearest to people: lexicographic, loop, hydrothermal, price, children, reddish, withholding, responses,
# Nearest to to: merely, towards, will, cloned, would, usta, in, not,
# Nearest to a: the, another, or, any, tba, microkernels, cauldron, ccitt,
# Nearest to history: nga, list, outbound, listing, dictionary, sickly, epa, knowledge,
# Average loss at step 42000: 3.437069
# Average loss at step 44000: 3.451463
# Average loss at step 46000: 3.450502
# Average loss at step 48000: 3.352168
# Average loss at step 50000: 3.382651
# Nearest to or: and, than, layla, botanicals, gleason, artful, like, xena,
# Nearest to some: many, several, these, both, other, most, those, dives,
# Nearest to which: that, this, who, also, usually, often, what, these,
# Nearest to however: but, although, while, that, though, when, during, storytelling,
# Nearest to that: which, however, oneida, frequentist, but, where, what, who,
# Nearest to about: procure, ghost, feed, kq, boulder, cameo, renounced, predictability,
# Nearest to between: with, against, regarding, while, hindsight, communication, among, yarmouth,
# Nearest to new: dagesh, cowley, inconsequential, marine, polycrates, fundamental, surpass, theoretical,
# Nearest to would: will, could, can, may, should, must, might, did,
# Nearest to use: cause, list, change, lao, create, destructive, form, swerve,
# Nearest to often: usually, sometimes, generally, typically, frequently, commonly, now, also,
# Nearest to so: then, lionhead, while, if, gets, ilois, guatemala, roque,
# Nearest to people: children, hydrothermal, lexicographic, price, withholding, jews, men, members,
# Nearest to to: could, hazard, gf, would, hallows, may, can, towards,
# Nearest to a: another, tba, the, microkernels, any, hasidic, no, apostates,
# Nearest to history: outbound, nga, list, listing, knowledge, leader, poignant, fallopian,
# Average loss at step 52000: 3.436976
# Average loss at step 54000: 3.423631
# Average loss at step 56000: 3.441837
# Average loss at step 58000: 3.397950
# Average loss at step 60000: 3.392446
# Nearest to or: and, than, artful, staining, talon, foretold, for, tray,
# Nearest to some: many, several, these, any, each, this, the, most,
# Nearest to which: that, this, what, who, usually, these, also, partnerships,
# Nearest to however: but, although, though, while, that, despite, when, during,
# Nearest to that: which, however, this, what, it, who, adr, there,
# Nearest to about: procure, feed, ghost, boulder, over, renounced, kq, cameo,
# Nearest to between: with, among, against, regarding, hindsight, yarmouth, communication, while,
# Nearest to new: marine, cowley, inconsequential, dagesh, theoretical, bitter, bactrian, fundamental,
# Nearest to would: will, could, may, can, might, should, must, did,
# Nearest to use: cause, change, sense, form, list, create, most, practice,
# Nearest to often: usually, sometimes, commonly, frequently, generally, typically, now, also,
# Nearest to so: then, workman, if, survived, roque, impatient, gets, too,
# Nearest to people: members, countries, men, hydrothermal, players, jews, children, scientists,
# Nearest to to: would, dassault, will, towards, gozo, subtitled, disdained, liberalization,
# Nearest to a: another, any, the, tba, seed, blackwell, apostates, multilinear,
# Nearest to history: geography, outbound, list, dandelion, listing, nga, continuation, troop,
# Average loss at step 62000: 3.240451
# Average loss at step 64000: 3.261871
# Average loss at step 66000: 3.401184
# Average loss at step 68000: 3.397624
# Average loss at step 70000: 3.361797
# Nearest to or: and, foretold, than, liter, staining, layla, buster, rubies,
# Nearest to some: many, several, these, both, most, various, any, their,
# Nearest to which: that, this, also, what, still, usually, it, but,
# Nearest to however: but, although, while, though, that, when, despite, where,
# Nearest to that: which, however, this, what, nevertheless, but, adr, where,
# Nearest to about: procure, boulder, on, over, keitai, regarding, renounced, insanity,
# Nearest to between: among, with, hindsight, regarding, from, around, against, yarmouth,
# Nearest to new: bactrian, cowley, marine, dagesh, fossil, icty, inconsequential, bandleader,
# Nearest to would: will, could, may, can, should, must, might, cannot,
# Nearest to use: cause, most, form, sense, needs, change, practice, list,
# Nearest to often: sometimes, usually, commonly, frequently, generally, typically, now, widely,
# Nearest to so: then, thus, too, gets, if, workman, roque, galloping,
# Nearest to people: men, children, hydrothermal, members, countries, wessel, persons, lexicographic,
# Nearest to to: can, would, will, mitzvot, subtitled, airstream, ghanima, must,
# Nearest to a: the, another, any, seed, tba, hasidic, apostates, microkernels,
# Nearest to history: list, outbound, listing, map, tip, geography, informatique, dandelion,
# Average loss at step 72000: 3.370324
# Average loss at step 74000: 3.351998
# Average loss at step 76000: 3.314388
# Average loss at step 78000: 3.349012
# Average loss at step 80000: 3.378512
# Nearest to or: and, than, while, artful, but, lethe, pyrite, ag,
# Nearest to some: many, several, these, most, numerous, various, both, any,
# Nearest to which: this, that, usually, also, who, what, impatient, but,
# Nearest to however: although, but, that, while, though, impatient, despite, since,
# Nearest to that: which, however, condom, but, where, aggadah, mouthwash, this,
# Nearest to about: procure, over, boulder, feed, least, regarding, keitai, ghost,
# Nearest to between: among, with, regarding, hindsight, around, within, yarmouth, over,
# Nearest to new: cowley, dagesh, bactrian, marine, fossil, southeastern, icty, broad,
# Nearest to would: will, could, may, can, might, must, should, cannot,
# Nearest to use: cause, form, list, sense, because, warhead, produce, treatment,
# Nearest to often: usually, sometimes, commonly, typically, generally, frequently, now, widely,
# Nearest to so: then, too, workman, gets, thus, officially, galloping, roque,
# Nearest to people: men, children, persons, members, lexicographic, women, those, jews,
# Nearest to to: would, hazard, gf, will, towards, nasir, could, trapdoor,
# Nearest to a: another, the, taira, tba, apostates, onshore, hasidic, senatus,
# Nearest to history: list, geography, janissaries, infamously, presidency, mastering, append, listing,
# Average loss at step 82000: 3.406096
# Average loss at step 84000: 3.408404
# Average loss at step 86000: 3.391926
# Average loss at step 88000: 3.351395
# Average loss at step 90000: 3.358590
# Nearest to or: and, than, artful, while, though, but, occupants, including,
# Nearest to some: many, several, these, any, both, this, numerous, most,
# Nearest to which: that, this, also, who, what, but, partnerships, nadi,
# Nearest to however: but, although, though, that, while, since, especially, during,
# Nearest to that: which, however, but, nevertheless, adr, what, oneida, indeed,
# Nearest to about: procure, over, regarding, keitai, feed, ghost, on, boulder,
# Nearest to between: with, among, regarding, within, against, around, under, hindsight,
# Nearest to new: cowley, marine, inconsequential, dagesh, thc, icty, bandleader, separate,
# Nearest to would: will, could, may, can, might, should, must, cannot,
# Nearest to use: list, practice, cause, warhead, form, treatment, needs, sense,
# Nearest to often: usually, sometimes, commonly, generally, typically, now, frequently, also,
# Nearest to so: then, too, gets, thus, workman, impatient, if, galloping,
# Nearest to people: men, children, women, members, persons, fans, hydrothermal, jews,
# Nearest to to: would, subtitled, towards, hazard, will, gf, must, rhetorical,
# Nearest to a: another, hasidic, any, every, the, tba, conservatively, enough,
# Nearest to history: list, geography, presidency, listing, dictionary, pits, dandelion, activex,
# Average loss at step 92000: 3.398251
# Average loss at step 94000: 3.251097
# Average loss at step 96000: 3.360753
# Average loss at step 98000: 3.245190
# Average loss at step 100000: 3.355577
# Nearest to or: and, than, gandy, eelam, consulates, layla, megawatts, thy,
# Nearest to some: many, several, these, numerous, any, certain, various, all,
# Nearest to which: that, this, who, what, usually, but, also, these,
# Nearest to however: but, although, though, that, while, especially, and, where,
# Nearest to that: which, however, what, who, this, indeed, adr, nevertheless,
# Nearest to about: procure, feed, keitai, approximately, boulder, chevrolet, ghost, least,
# Nearest to between: with, among, hindsight, regarding, against, within, around, disseminate,
# Nearest to new: cowley, bactrian, different, separate, icty, pgs, cornet, bandleader,
# Nearest to would: will, could, may, might, can, should, must, cannot,
# Nearest to use: cause, list, form, sense, miata, practice, warhead, because,
# Nearest to often: usually, sometimes, commonly, generally, typically, frequently, now, normally,
# Nearest to so: then, too, thus, gets, impatient, if, when, tisdall,
# Nearest to people: children, men, jews, hydrothermal, fans, women, players, persons,
# Nearest to to: towards, will, would, could, should, and, can, must,
# Nearest to a: another, the, any, senatus, microkernels, enough, mahogany, every,
# Nearest to history: list, geography, unbeatable, presidency, gumbo, map, listing, fer,

# %%
num_points = 400

tsne = TSNE(perplexity=30, n_components=2, init='pca', n_iter=5000)
two_d_embeddings = tsne.fit_transform(final_embeddings[1:num_points+1, :])

# %%
def plot(embeddings, labels):
  assert embeddings.shape[0] >= len(labels), 'More labels than embeddings'
  pylab.figure(figsize=(15,15))  # in inches
  for i, label in enumerate(labels):
    x, y = embeddings[i,:]
    pylab.scatter(x, y)
    pylab.annotate(label, xy=(x, y), xytext=(5, 2), textcoords='offset points',
                   ha='right', va='bottom')
  pylab.show()

words = [reverse_dictionary[i] for i in range(1, num_points+1)]
plot(two_d_embeddings, words)

# %% [markdown]
# ---
#
# Problem
# -------
#
# An alternative to skip-gram is another Word2Vec model called [CBOW](http://arxiv.org/abs/1301.3781) (Continuous Bag of Words). In the CBOW model, instead of predicting a context word from a word vector, you predict a word from the sum of all the word vectors in its context. Implement and evaluate a CBOW model trained on the text8 dataset.
#
# ---

# %%
data_index = 0

def generate_batch(batch_size, bag_window):
  global data_index
  span = 2 * bag_window + 1 # [ bag_window target bag_window ]
  batch = np.ndarray(shape=(batch_size, span - 1), dtype=np.int32)
  labels = np.ndarray(shape=(batch_size, 1), dtype=np.int32)  
  buffer = collections.deque(maxlen=span)
  for _ in range(span):
    buffer.append(data[data_index])
    data_index = (data_index + 1) % len(data)
  for i in range(batch_size):
    # just for testing
    buffer_list = list(buffer)
    labels[i, 0] = buffer_list.pop(bag_window)
    batch[i] = buffer_list
    # iterate to the next buffer
    buffer.append(data[data_index])
    data_index = (data_index + 1) % len(data)
  return batch, labels

print('data:', [reverse_dictionary[di] for di in data[:16]])

for bag_window in [1, 2]:
  data_index = 0
  batch, labels = generate_batch(batch_size=4, bag_window=bag_window)
  print('\nwith bag_window = %d:' % (bag_window))  
  print('    batch:', [[reverse_dictionary[w] for w in bi] for bi in batch])  
  print('    labels:', [reverse_dictionary[li] for li in labels.reshape(4)])
# Out:
# data: ['anarchism', 'originated', 'as', 'a', 'term', 'of', 'abuse', 'first', 'used', 'against', 'early', 'working', 'class', 'radicals', 'including', 'the']
#
# with bag_window = 1:
#     batch: [['anarchism', 'as'], ['originated', 'a'], ['as', 'term'], ['a', 'of']]
#     labels: ['originated', 'as', 'a', 'term']
#
# with bag_window = 2:
#     batch: [['anarchism', 'originated', 'a', 'term'], ['originated', 'as', 'term', 'of'], ['as', 'a', 'of', 'abuse'], ['a', 'term', 'abuse', 'first']]
#     labels: ['as', 'a', 'term', 'of']

# %%
batch_size = 128
embedding_size = 128 # Dimension of the embedding vector.
skip_window = 1 # How many words to consider left and right.
num_skips = 2 # How many times to reuse an input to generate a label.
bag_window = 2 # How many words to consider left and right.
# We pick a random validation set to sample nearest neighbors. here we limit the
# validation samples to the words that have a low numeric ID, which by
# construction are also the most frequent. 
valid_size = 16 # Random set of words to evaluate similarity on.
valid_window = 100 # Only pick dev samples in the head of the distribution.
valid_examples = np.array(random.sample(range(valid_window), valid_size))
num_sampled = 64 # Number of negative examples to sample.

graph = tf.Graph()

with graph.as_default(), tf.device('/cpu:0'):

  # Input data.
  train_dataset = tf.placeholder(tf.int32, shape=[batch_size, bag_window * 2])
  train_labels = tf.placeholder(tf.int32, shape=[batch_size, 1])
  valid_dataset = tf.constant(valid_examples, dtype=tf.int32)
  
  # Variables.
  embeddings = tf.Variable(
    tf.random_uniform([vocabulary_size, embedding_size], -1.0, 1.0))
  softmax_weights = tf.Variable(
    tf.truncated_normal([vocabulary_size, embedding_size],
                         stddev=1.0 / math.sqrt(embedding_size)))
  softmax_biases = tf.Variable(tf.zeros([vocabulary_size]))
  
  # Model.
  # Look up embeddings for inputs.
  embed = tf.nn.embedding_lookup(embeddings, train_dataset)
  # Compute the softmax loss, using a sample of the negative labels each time.
  loss = tf.reduce_mean(
    tf.nn.sampled_softmax_loss(softmax_weights, softmax_biases, tf.reduce_sum(embed, 1),
                               train_labels, num_sampled, vocabulary_size))

  # Optimizer.
  # Note: The optimizer will optimize the softmax_weights AND the embeddings.
  # This is because the embeddings are defined as a variable quantity and the
  # optimizer's `minimize` method will by default modify all variable quantities 
  # that contribute to the tensor it is passed.
  # See docs on `tf.train.Optimizer.minimize()` for more details.
  optimizer = tf.train.AdagradOptimizer(1.0).minimize(loss)
  
  # Compute the similarity between minibatch examples and all embeddings.
  # We use the cosine distance:
  norm = tf.sqrt(tf.reduce_sum(tf.square(embeddings), 1, keep_dims=True))
  normalized_embeddings = embeddings / norm
  valid_embeddings = tf.nn.embedding_lookup(
    normalized_embeddings, valid_dataset)
  similarity = tf.matmul(valid_embeddings, tf.transpose(normalized_embeddings))

# %%
num_steps = 100001

with tf.Session(graph=graph) as session:
  tf.initialize_all_variables().run()
  print('Initialized')
  average_loss = 0
  for step in range(num_steps):
    batch_data, batch_labels = generate_batch(
      batch_size, bag_window)
    feed_dict = {train_dataset : batch_data, train_labels : batch_labels}
    _, l = session.run([optimizer, loss], feed_dict=feed_dict)
    average_loss += l
    if step % 2000 == 0:
      if step > 0:
        average_loss = average_loss / 2000
      # The average loss is an estimate of the loss over the last 2000 batches.
      print('Average loss at step %d: %f' % (step, average_loss))
      average_loss = 0
    # note that this is expensive (~20% slowdown if computed every 500 steps)
    if step % 10000 == 0:
      sim = similarity.eval()
      for i in range(valid_size):
        valid_word = reverse_dictionary[valid_examples[i]]
        top_k = 8 # number of nearest neighbors
        nearest = (-sim[i, :]).argsort()[1:top_k+1]
        log = 'Nearest to %s:' % valid_word
        for k in range(top_k):
          close_word = reverse_dictionary[nearest[k]]
          log = '%s %s,' % (log, close_word)
        print(log)
  final_embeddings = normalized_embeddings.eval()
# Out:
# Initialized
# Average loss at step 0: 7.394686
# Nearest to nine: tp, inexplicably, alder, boitano, mauryan, rbis, queer, wg,
# Nearest to would: neri, frontispiece, normality, waved, disappear, henson, nme, prodigal,
# Nearest to be: radon, sufficiently, oncoming, ry, braudel, dever, mediocre, termites,
# Nearest to seven: realign, planetfall, peasant, nerve, slept, ayub, boggs, chalk,
# Nearest to years: holies, romania, mihdhar, clarence, concession, kramer, paradigmatic, financed,
# Nearest to this: celtiberian, summands, barks, saiyan, testing, witty, tivoli, martial,
# Nearest to were: begs, incompatible, undergo, exerts, experimenter, traction, way, behaves,
# Nearest to world: mercator, irate, ev, hail, encke, heterochromatin, marge, houser,
# Nearest to only: motors, wikiproject, scullin, zappa, during, honeybee, fulfilment, macrinus,
# Nearest to more: cryptosystems, reared, padawan, einstein, viol, secede, undifferentiated, rainer,
# Nearest to its: there, schwarz, hopper, suffix, wolfenstein, linguistic, sampler, mentat,
# Nearest to first: ai, israeli, aircrew, cladistic, javascript, fours, mankiewicz, shrinks,
# Nearest to over: hellbender, marginalized, aerosmith, bosco, india, komondor, strikes, emedicine,
# Nearest to but: altos, inferred, barnum, addressed, flames, tabulate, devotee, binds,
# Nearest to may: pooling, transylvania, liked, hecuba, fsf, monosaccharide, operation, alexandrine,
# Nearest to called: hoplite, cracker, opencourseware, cable, befriended, cognitivism, hamad, droplets,
# Average loss at step 2000: 11.280976
# Average loss at step 4000: 7.015216
# Average loss at step 6000: 5.339460
# Average loss at step 8000: 5.559384
# Average loss at step 10000: 4.566939
# Nearest to nine: eight, six, zero, three, seven, two, bottlers, torre,
# Nearest to would: may, can, could, will, should, must, might, does,
# Nearest to be: refer, have, lead, clemens, are, apply, oncoming, elevations,
# Nearest to seven: five, four, eight, six, nine, zero, boast, shaft,
# Nearest to years: unarable, ratchet, shines, centuries, judi, maguey, people, empowering,
# Nearest to this: it, the, a, any, which, sanctity, another, summands,
# Nearest to were: are, was, had, brontosaurus, supermarkets, seoul, artificially, richard,
# Nearest to world: audiovisual, contributor, bannerman, chissano, dexter, mercator, consortium, hides,
# Nearest to only: maddox, passover, sca, conjectured, tangled, teen, daddah, motors,
# Nearest to more: less, most, rather, strengthened, artifice, dostum, immanence, ponce,
# Nearest to its: their, his, the, yearly, her, intuitionism, iala, singled,
# Nearest to first: dive, moon, jeb, rabban, defend, sachet, para, class,
# Nearest to over: into, egregious, maroon, minnie, obituary, marginalized, ceiling, gynecology,
# Nearest to but: although, though, und, and, however, audacity, hypothetically, invertible,
# Nearest to may: would, can, could, will, must, should, to, cannot,
# Nearest to called: nee, hoplite, interrogators, wargame, harbor, raptor, occupants, there,
# Average loss at step 12000: 4.084752
# Average loss at step 14000: 4.367847
# Average loss at step 16000: 4.031673
# Average loss at step 18000: 3.937191
# Average loss at step 20000: 4.160640
# Nearest to nine: zero, six, northumbria, peripatetic, basilica, wilbur, molecules, mellitus,
# Nearest to would: will, may, should, could, can, must, might, did,
# Nearest to be: refer, lead, being, clemens, kokhba, produce, go, mean,
# Nearest to seven: eight, five, four, arsenic, aloe, islands, ascii, amaranth,
# Nearest to years: apollo, advertising, female, organisms, api, animals, living, woz,
# Nearest to this: which, what, yunnan, any, garbo, the, eurythmics, another,
# Nearest to were: are, was, is, had, being, broadway, lionhead, became,
# Nearest to world: footnote, cassini, levites, cubical, jasmuheen, trojan, codex, fiend,
# Nearest to only: first, franca, linguists, mencken, conjectured, instantly, jeb, scapegoat,
# Nearest to more: less, rather, very, greater, most, faster, artifice, larger,
# Nearest to its: their, the, canaries, his, musicology, rds, canceling, alejandro,
# Nearest to first: last, second, next, infinity, same, sachet, notification, grazing,
# Nearest to over: during, under, callisto, widest, within, at, into, beeching,
# Nearest to but: while, and, beria, however, though, than, although, bottlenose,
# Nearest to may: can, would, will, should, could, must, cannot, might,
# Nearest to called: considered, used, known, contributors, rca, nee, freighters, unary,
# Average loss at step 22000: 3.586631
# Average loss at step 24000: 3.462290
# Average loss at step 26000: 3.481012
# Average loss at step 28000: 3.654081
# Average loss at step 30000: 3.704995
# Nearest to nine: eight, six, five, zero, four, th, march, november,
# Nearest to would: could, should, can, must, will, might, may, did,
# Nearest to be: being, lead, refer, remain, serve, produce, been, apply,
# Nearest to seven: eight, zero, three, six, islands, maguey, lycanthropy, gang,
# Nearest to years: months, days, year, maguey, unarable, decades, week, ridge,
# Nearest to this: it, which, garbo, that, what, jaffna, the, an,
# Nearest to were: are, was, had, is, kearns, being, have, coercive,
# Nearest to world: vietnam, city, place, cassini, abwehr, troublesome, completing, levites,
# Nearest to only: proactive, franca, daddah, ctor, first, montenegrin, startled, sca,
# Nearest to more: less, rather, faster, too, better, greater, very, larger,
# Nearest to its: their, his, her, the, endings, labor, catalyse, goodies,
# Nearest to first: last, second, third, next, same, codec, sulu, original,
# Nearest to over: through, before, during, around, across, maroon, finally, off,
# Nearest to but: although, than, however, while, and, see, though, fsm,
# Nearest to may: can, would, will, might, must, could, should, cannot,
# Nearest to called: used, known, there, contributors, rca, entrepreneurs, doctorate, buckets,
# Average loss at step 32000: 3.224596
# Average loss at step 34000: 3.367893
# Average loss at step 36000: 3.579762
# Average loss at step 38000: 3.449645
# Average loss at step 40000: 3.348820
# Nearest to nine: eight, seven, five, six, palpatine, four, late, sinn,
# Nearest to would: could, will, may, might, should, can, must, cannot,
# Nearest to be: being, lead, refer, occur, remain, kokhba, apply, been,
# Nearest to seven: eight, five, six, four, three, nine, zero, underrated,
# Nearest to years: months, days, decades, centuries, year, hours, decade, minutes,
# Nearest to this: which, it, that, what, jaffna, the, some, another,
# Nearest to were: are, was, is, had, include, being, kearns, have,
# Nearest to world: industry, cassini, counteract, sparse, city, etymologically, longstreet, intestines,
# Nearest to only: usually, best, town, specifically, now, taliesin, already, elected,
# Nearest to more: less, rather, most, very, too, greater, larger, stronger,
# Nearest to its: their, his, the, your, our, her, my, whose,
# Nearest to first: last, second, third, next, best, same, original, commonsense,
# Nearest to over: finally, egregious, throughout, during, before, across, modesty, about,
# Nearest to but: however, and, although, while, than, though, magdalena, bauds,
# Nearest to may: can, would, will, might, could, must, should, cannot,
# Nearest to called: considered, found, included, blues, nominees, declared, created, signature,
# Average loss at step 42000: 3.396677
# Average loss at step 44000: 3.401975
# Average loss at step 46000: 3.372444
# Average loss at step 48000: 3.237529
# Average loss at step 50000: 3.254522
# Nearest to nine: eight, seven, five, six, zero, four, th, three,
# Nearest to would: will, could, may, should, might, can, must, cannot,
# Nearest to be: himself, get, return, move, agree, replace, adopt, scheduling,
# Nearest to seven: eight, five, six, nine, four, three, zero, usher,
# Nearest to years: months, days, centuries, decades, hours, year, minutes, times,
# Nearest to this: which, another, it, what, a, the, summands, erd,
# Nearest to were: are, was, is, being, be, include, had, hobsbawm,
# Nearest to world: mandrakesoft, industry, city, emperor, show, era, fon, unlikely,
# Nearest to only: always, still, even, usually, celsius, borne, forged, assassins,
# Nearest to more: less, rather, greater, better, too, very, larger, most,
# Nearest to its: their, his, the, our, her, your, minuet, yearly,
# Nearest to first: next, second, third, last, same, original, sulu, final,
# Nearest to over: around, through, egregious, across, before, during, between, rshavn,
# Nearest to but: although, though, and, while, than, tonne, stirrup, however,
# Nearest to may: can, would, might, could, must, will, should, cannot,
# Nearest to called: considered, used, joined, named, known, kos, created, produced,
# Average loss at step 52000: 3.241132
# Average loss at step 54000: 3.214118
# Average loss at step 56000: 3.070705
# Average loss at step 58000: 3.148403
# Average loss at step 60000: 3.229354
# Nearest to nine: eight, seven, zero, six, five, four, two, late,
# Nearest to would: should, can, could, may, must, might, will, did,
# Nearest to be: power, either, scheduling, change, itself, room, estimators, caddy,
# Nearest to seven: eight, four, six, five, three, nine, zero, two,
# Nearest to years: days, decades, centuries, hours, minutes, year, decade, months,
# Nearest to this: every, eac, it, current, itself, tease, some, easily,
# Nearest to were: are, was, is, being, include, have, kearns, hasidim,
# Nearest to world: show, bolsheviks, accomplished, wozniak, dkk, acidic, hope, sport,
# Nearest to only: still, always, usually, however, arthurian, even, cade, ecclesiastics,
# Nearest to more: less, rather, greater, very, better, quite, relatively, larger,
# Nearest to its: their, his, her, the, our, whose, your, my,
# Nearest to first: last, second, next, third, predated, donkey, codec, same,
# Nearest to over: nearly, enjoy, heartland, ab, eventual, almost, tubular, ve,
# Nearest to but: however, and, although, than, though, while, torrent, tonne,
# Nearest to may: could, must, should, can, would, might, will, cannot,
# Nearest to called: considered, used, formed, named, created, referred, attributed, introduced,
# Average loss at step 62000: 3.270771
# Average loss at step 64000: 3.083893
# Average loss at step 66000: 3.084361
# Average loss at step 68000: 3.093906
# Average loss at step 70000: 3.120188
# Nearest to nine: eight, zero, th, colspan, december, july, palpatine, scalpel,
# Nearest to would: will, could, might, should, may, can, must, cannot,
# Nearest to be: lead, being, refer, apply, provide, cause, occur, produce,
# Nearest to seven: six, eight, four, three, five, zero, two, cimmeria,
# Nearest to years: days, decades, months, centuries, hours, minutes, decade, weeks,
# Nearest to this: which, it, jaffna, equine, what, statistically, fontsize, that,
# Nearest to were: are, was, remain, kicks, emperors, agree, conforming, isospin,
# Nearest to world: dkk, controversy, statuary, footnote, city, ama, tesco, eternity,
# Nearest to only: always, actually, problematic, it, even, nine, stiles, already,
# Nearest to more: less, rather, very, larger, greater, smaller, faster, too,
# Nearest to its: their, his, her, the, our, your, my, ultimatum,
# Nearest to first: last, second, third, next, same, original, throughout, ninth,
# Nearest to over: around, through, worldwide, across, throughout, sovereign, during, under,
# Nearest to but: because, though, gaku, han, temmu, praetors, than, deleted,
# Nearest to may: might, should, must, will, can, could, would, cannot,
# Nearest to called: known, signature, eac, k, forming, nominees, blues, blackwood,
# Average loss at step 72000: 3.052297
# Average loss at step 74000: 2.959543
# Average loss at step 76000: 3.068095
# Average loss at step 78000: 3.112181
# Average loss at step 80000: 2.951034
# Nearest to nine: eight, six, zero, four, three, five, january, december,
# Nearest to would: will, could, might, may, should, can, cannot, must,
# Nearest to be: lead, refer, being, represent, provide, remain, produce, apply,
# Nearest to seven: caddy, blackwood, stuttgart, pdg, card, peano, initio, mostly,
# Nearest to years: months, decades, year, centuries, minutes, hours, decade, seconds,
# Nearest to this: which, it, another, fontsize, that, donut, kiki, a,
# Nearest to were: are, was, is, newly, include, mush, kabbalah, had,
# Nearest to world: city, country, tesco, dkk, option, cassini, controversy, estate,
# Nearest to only: always, even, simply, widely, fielders, virulence, already, best,
# Nearest to more: less, greater, very, rather, too, larger, better, quite,
# Nearest to its: their, his, the, her, our, whose, your, my,
# Nearest to first: last, next, second, third, same, original, ninth, earliest,
# Nearest to over: throughout, across, worldwide, drowning, almost, about, sovereign, within,
# Nearest to but: though, however, although, which, and, see, norris, because,
# Nearest to may: could, might, would, cannot, can, will, should, must,
# Nearest to called: named, considered, played, attributed, used, joined, jujutsu, described,
# Average loss at step 82000: 3.019905
# Average loss at step 84000: 2.946889
# Average loss at step 86000: 3.005386
# Average loss at step 88000: 3.053776
# Average loss at step 90000: 2.947052
# Nearest to nine: seven, eight, six, zero, late, five, four, th,
# Nearest to would: should, could, might, will, may, can, must, did,
# Nearest to be: lead, remain, being, represent, refer, serve, occur, provide,
# Nearest to seven: eight, three, six, four, five, nine, zero, one,
# Nearest to years: months, days, decades, weeks, centuries, year, hours, minutes,
# Nearest to this: it, which, another, what, a, every, any, that,
# Nearest to were: are, was, include, is, andromache, mush, exist, clooney,
# Nearest to world: universe, country, bolsheviks, trojan, decorate, rays, dkk, controversy,
# Nearest to only: scheduling, always, rda, card, debunking, particularly, peano, latency,
# Nearest to more: less, highly, faster, rather, better, older, particularly, debunking,
# Nearest to its: their, the, his, your, our, her, whose, squealer,
# Nearest to first: last, second, next, third, fifth, fourth, same, worst,
# Nearest to over: around, throughout, under, during, almost, within, about, maroon,
# Nearest to but: although, however, though, ennius, while, and, like, than,
# Nearest to may: might, can, should, could, must, would, will, cannot,
# Nearest to called: named, considered, introduced, known, used, joined, played, added,
# Average loss at step 92000: 2.964087
# Average loss at step 94000: 3.008605
# Average loss at step 96000: 2.785326
# Average loss at step 98000: 2.742010
# Average loss at step 100000: 2.796890
# Nearest to nine: eight, seven, zero, six, five, four, june, july,
# Nearest to would: might, will, could, should, must, can, may, cannot,
# Nearest to be: remain, being, occur, refer, lead, serve, get, become,
# Nearest to seven: six, four, five, eight, three, nine, zero, maguey,
# Nearest to years: months, weeks, decades, year, commonsense, disagreement, disciplines, minutes,
# Nearest to this: which, present, another, still, prophylaxis, euskadi, peano, imdb,
# Nearest to were: are, several, mckellen, eisenach, faro, clotting, isospin, while,
# Nearest to world: trojan, rays, equator, acidic, universe, nation, dkk, city,
# Nearest to only: always, first, last, best, damn, monastic, no, bracelet,
# Nearest to more: less, rather, better, quite, most, very, smaller, faster,
# Nearest to its: their, his, her, the, our, whose, squealer, presumes,
# Nearest to first: last, second, third, next, worst, same, earliest, only,
# Nearest to over: around, throughout, through, across, about, down, under, transfiguration,
# Nearest to but: however, and, although, though, while, or, namur, than,
# Nearest to may: might, must, should, could, can, will, would, cannot,
# Nearest to called: named, used, added, considered, released, described, entitled, abandoned,

# %%
num_points = 400

tsne = TSNE(perplexity=30, n_components=2, init='pca', n_iter=5000)
two_d_embeddings = tsne.fit_transform(final_embeddings[1:num_points+1, :])


def plot(embeddings, labels):
  assert embeddings.shape[0] >= len(labels), 'More labels than embeddings'
  pylab.figure(figsize=(15,15))  # in inches
  for i, label in enumerate(labels):
    x, y = embeddings[i,:]
    pylab.scatter(x, y)
    pylab.annotate(label, xy=(x, y), xytext=(5, 2), textcoords='offset points',
                   ha='right', va='bottom')
  pylab.show()

words = [reverse_dictionary[i] for i in range(1, num_points+1)]
plot(two_d_embeddings, words)
